# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import time
import numpy as np
import random
import statsmodels.api as sm
import statsmodels.stats.diagnostic as smd
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
import seaborn as sns
import statsmodels.api as sm
import scipy.stats as stats
import statsmodels.stats.diagnostic as diag
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.impute import SimpleImputer

from sklearn.compose import make_column_selector as selector #Para seleccionar de forma automática las variables numéricas y categóricas
from sklearn.preprocessing import OneHotEncoder #Para codificar las variables categóricas usando dummies
from sklearn.preprocessing import StandardScaler #Para normalizar las variables numéricas
from sklearn.compose import ColumnTransformer #Modifica las columnas usando los preprocesadores
from sklearn.pipeline import make_pipeline #Planifica una secuencia de procesos
from sklearn import set_config #Para mostrar graficamente el pipeline
from sklearn.model_selection import GridSearchCV

set_config(display='diagram')
#Metrics
from sklearn.metrics import make_scorer, accuracy_score,precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score

from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import learning_curve
import time
from sklearn.exceptions import ConvergenceWarning

# %%
df = pd.read_csv('train.csv')
df_clean = df.dropna(subset=['OverallQual', 'GrLivArea', 'TotalBsmtSF', 'SalePrice'])


print("Dimensiones del DataFrame:", df.shape)
print(df.head())
# Out:
# Dimensiones del DataFrame: (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df_clean = df.dropna(subset=['OverallQual', 'GrLivArea', 'TotalBsmtSF', 'SalePrice'])

precio_33 = np.percentile(df_clean['SalePrice'], 33)
precio_66 = np.percentile(df_clean['SalePrice'], 66)

def categorizar_precio(precio):
    if precio <= precio_33:
        return 'Económica'
    elif precio <= precio_66:
        return 'Intermedia'
    else:
        return 'Cara'


df_clean['PriceCategory'] = df_clean['SalePrice'].apply(categorizar_precio)

print(df_clean['PriceCategory'].value_counts(normalize=True))
# Out:
# PriceCategory
# Cara          0.340411
# Económica     0.330822
# Intermedia    0.328767
# Name: proportion, dtype: float64

# %%
X = df_clean.drop(['Id','SalePrice','PriceCategory'], axis=1)
y = df_clean['PriceCategory']


X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)


preprocesador = ColumnTransformer([
    ("num", make_pipeline(
        SimpleImputer(strategy="median"),
        StandardScaler()
    ), selector(dtype_include=["int64","float64"])),
    ("cat", make_pipeline(
        SimpleImputer(strategy="most_frequent"),
        OneHotEncoder(handle_unknown="ignore")
    ), selector(dtype_include=object))
])


# Usa 'preprocessor_fixed' en lugar de 'preprocesador'
modelo1 = make_pipeline(
    preprocesador,
    MLPClassifier(hidden_layer_sizes=(5,3), activation="tanh", solver="adam", max_iter=300, verbose=True, random_state=42)
)
modelo2 = make_pipeline(
    preprocesador,
    MLPClassifier(hidden_layer_sizes=(10,5), activation="relu", solver="adam", max_iter=300, verbose=True, random_state=42)
)

# Entrena y evalúa
modelo1.fit(X_train, y_train)
modelo2.fit(X_train, y_train)
# … evaluación como antes …


# Evaluar los modelos en el conjunto de prueba
for i, modelo in enumerate([modelo1, modelo2], start=1):
    y_pred = modelo.predict(X_test)
    print(f"\n--- Evaluación Modelo {i} ---")
    print("Accuracy :", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred, average='weighted'))
    print("Recall   :", recall_score(y_test, y_pred, average='weighted'))
    print("F1-score :", f1_score(y_test, y_pred, average='weighted'))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Iteration 1, loss = 1.19514329
# Iteration 2, loss = 1.09905710
# Iteration 3, loss = 1.01297718
# Iteration 4, loss = 0.94013716
# Iteration 5, loss = 0.87743444
# Iteration 6, loss = 0.83291879
# Iteration 7, loss = 0.79894293
# Iteration 8, loss = 0.77114572
# Iteration 9, loss = 0.74849473
# Iteration 10, loss = 0.72914893
# Iteration 11, loss = 0.71272449
# Iteration 12, loss = 0.69745531
# Iteration 13, loss = 0.68380692
# Iteration 14, loss = 0.67112269
# Iteration 15, loss = 0.65955715
# Iteration 16, loss = 0.64923108
# Iteration 17, loss = 0.63872574
# Iteration 18, loss = 0.62899549
# Iteration 19, loss = 0.61976816
# Iteration 20, loss = 0.61053097
# Iteration 21, loss = 0.60181694
# Iteration 22, loss = 0.59314861
# Iteration 23, loss = 0.58499923
# Iteration 24, loss = 0.57694785
# Iteration 25, loss = 0.56887984
# Iteration 26, loss = 0.56112805
# Iteration 27, loss = 0.55348571
# Iteration 28, loss = 0.54591316
# Iteration 29, loss = 0.53858579
# Iteration 30, loss = 0.53179884
# Iteration 31, loss = 0.52466459
# Iteration 32, loss = 0.51789753
# Iteration 33, loss = 0.51129034
# Iteration 34, loss = 0.50508550
# Iteration 35, loss = 0.49875602
# Iteration 36, loss = 0.49279017
# Iteration 37, loss = 0.48686000
# Iteration 38, loss = 0.48120348
# Iteration 39, loss = 0.47565517
# Iteration 40, loss = 0.47001391
# Iteration 41, loss = 0.46468454
# Iteration 42, loss = 0.45975298
# Iteration 43, loss = 0.45459875
# Iteration 44, loss = 0.44897208
# Iteration 45, loss = 0.44373309
# Iteration 46, loss = 0.43914367
# Iteration 47, loss = 0.43426621
# Iteration 48, loss = 0.42939162
# Iteration 49, loss = 0.42481040
# Iteration 50, loss = 0.42002680
# Iteration 51, loss = 0.41580441
# Iteration 52, loss = 0.41135493
# Iteration 53, loss = 0.40674520
# Iteration 54, loss = 0.40233016
# Iteration 55, loss = 0.39813829
# Iteration 56, loss = 0.39371969
# Iteration 57, loss = 0.38951580
# Iteration 58, loss = 0.38558499
# Iteration 59, loss = 0.38125106
# Iteration 60, loss = 0.37787304
# Iteration 61, loss = 0.37304761
# Iteration 62, loss = 0.36936183
# Iteration 63, loss = 0.36543306
# Iteration 64, loss = 0.36163516
# Iteration 65, loss = 0.35759337
# Iteration 66, loss = 0.35429494
# Iteration 67, loss = 0.35022477
# Iteration 68, loss = 0.34666264
# Iteration 69, loss = 0.34291255
# Iteration 70, loss = 0.33994215
# Iteration 71, loss = 0.33673293
# Iteration 72, loss = 0.33244287
# Iteration 73, loss = 0.32843294
# Iteration 74, loss = 0.32502504
# Iteration 75, loss = 0.32204166
# Iteration 76, loss = 0.31821650
# Iteration 77, loss = 0.31477205
# Iteration 78, loss = 0.31164024
# Iteration 79, loss = 0.30808327
# Iteration 80, loss = 0.30531149
# Iteration 81, loss = 0.30199266
# Iteration 82, loss = 0.29875054
# Iteration 83, loss = 0.29597459
# Iteration 84, loss = 0.29261986
# Iteration 85, loss = 0.28972999
# Iteration 86, loss = 0.28687806
# Iteration 87, loss = 0.28415771
# Iteration 88, loss = 0.28145192
# Iteration 89, loss = 0.27873252
# Iteration 90, loss = 0.27682959
# Iteration 91, loss = 0.27367466
# Iteration 92, loss = 0.27112943
# Iteration 93, loss = 0.26871253
# Iteration 94, loss = 0.26677784
# Iteration 95, loss = 0.26392488
# Iteration 96, loss = 0.26212510
# Iteration 97, loss = 0.25943767
# Iteration 98, loss = 0.25748429
# Iteration 99, loss = 0.25603216
# Iteration 100, loss = 0.25308737
# Iteration 101, loss = 0.25207288
# Iteration 102, loss = 0.24933696
# Iteration 103, loss = 0.24802584
# Iteration 104, loss = 0.24533918
# Iteration 105, loss = 0.24377868
# Iteration 106, loss = 0.24183453
# Iteration 107, loss = 0.23948077
# Iteration 108, loss = 0.23753665
# Iteration 109, loss = 0.23590382
# Iteration 110, loss = 0.23424205
# Iteration 111, loss = 0.23296475
# Iteration 112, loss = 0.23035654
# Iteration 113, loss = 0.22948571
# Iteration 114, loss = 0.22819531
# Iteration 115, loss = 0.22631553
# Iteration 116, loss = 0.22468198
# Iteration 117, loss = 0.22198643
# Iteration 118, loss = 0.22049296
# Iteration 119, loss = 0.21965146
# Iteration 120, loss = 0.21744046
# Iteration 121, loss = 0.21609505
# Iteration 122, loss = 0.21392662
# Iteration 123, loss = 0.21269934
# Iteration 124, loss = 0.21102291
# Iteration 125, loss = 0.20935630
# Iteration 126, loss = 0.20774039
# Iteration 127, loss = 0.20647489
# Iteration 128, loss = 0.20499867
# Iteration 129, loss = 0.20394418
# Iteration 130, loss = 0.20255401
# Iteration 131, loss = 0.20067551
# Iteration 132, loss = 0.19979116
# Iteration 133, loss = 0.19823968
# Iteration 134, loss = 0.19718022
# Iteration 135, loss = 0.19570526
# Iteration 136, loss = 0.19470276
# Iteration 137, loss = 0.19328053
# Iteration 138, loss = 0.19233562
# Iteration 139, loss = 0.18999467
# Iteration 140, loss = 0.18945590
# Iteration 141, loss = 0.18823936
# Iteration 142, loss = 0.18640129
# Iteration 143, loss = 0.18628384
# Iteration 144, loss = 0.18509703
# Iteration 145, loss = 0.18407376
# Iteration 146, loss = 0.18330739
# Iteration 147, loss = 0.18133560
# Iteration 148, loss = 0.18040647
# Iteration 149, loss = 0.18072281
# Iteration 150, loss = 0.17752971
# Iteration 151, loss = 0.17709899
# Iteration 152, loss = 0.17576921
# Iteration 153, loss = 0.17557314
# Iteration 154, loss = 0.17380212
# Iteration 155, loss = 0.17283767
# Iteration 156, loss = 0.17178015
# Iteration 157, loss = 0.17061862
# Iteration 158, loss = 0.16958334
# Iteration 159, loss = 0.16884229
# Iteration 160, loss = 0.16798375
# Iteration 161, loss = 0.16733821
# Iteration 162, loss = 0.16614446
# Iteration 163, loss = 0.16600968
# Iteration 164, loss = 0.16432428
# Iteration 165, loss = 0.16468259
# Iteration 166, loss = 0.16460828
# Iteration 167, loss = 0.16251896
# Iteration 168, loss = 0.16147423
# Iteration 169, loss = 0.16102998
# Iteration 170, loss = 0.15909619
# Iteration 171, loss = 0.15875106
# Iteration 172, loss = 0.15726855
# Iteration 173, loss = 0.15684720
# Iteration 174, loss = 0.15555675
# Iteration 175, loss = 0.15491719
# Iteration 176, loss = 0.15426269
# Iteration 177, loss = 0.15385998
# Iteration 178, loss = 0.15231595
# Iteration 179, loss = 0.15275770
# Iteration 180, loss = 0.15157696
# Iteration 181, loss = 0.15025609
# Iteration 182, loss = 0.14965392
# Iteration 183, loss = 0.14846951
# Iteration 184, loss = 0.14799590
# Iteration 185, loss = 0.14707072
# Iteration 186, loss = 0.14712756
# Iteration 187, loss = 0.14602085
# Iteration 188, loss = 0.14516811
# Iteration 189, loss = 0.14394820
# Iteration 190, loss = 0.14361559
# Iteration 191, loss = 0.14277434
# Iteration 192, loss = 0.14192375
# Iteration 193, loss = 0.14084364
# Iteration 194, loss = 0.14057657
# Iteration 195, loss = 0.13918758
# Iteration 196, loss = 0.13880662
# Iteration 197, loss = 0.13801809
# Iteration 198, loss = 0.13726436
# Iteration 199, loss = 0.13682287
# Iteration 200, loss = 0.13622938
# Iteration 201, loss = 0.13531390
# Iteration 202, loss = 0.13427202
# Iteration 203, loss = 0.13350068
# Iteration 204, loss = 0.13257477
# Iteration 205, loss = 0.13219943
# Iteration 206, loss = 0.13163847
# Iteration 207, loss = 0.13018848
# Iteration 208, loss = 0.12988520
# Iteration 209, loss = 0.12899252
# Iteration 210, loss = 0.12873068
# Iteration 211, loss = 0.12773510
# Iteration 212, loss = 0.12662431
# Iteration 213, loss = 0.12632465
# Iteration 214, loss = 0.12537611
# Iteration 215, loss = 0.12440626
# Iteration 216, loss = 0.12372808
# Iteration 217, loss = 0.12293916
# Iteration 218, loss = 0.12216312
# Iteration 219, loss = 0.12148394
# Iteration 220, loss = 0.12050109
# Iteration 221, loss = 0.12076557
# Iteration 222, loss = 0.11944241
# Iteration 223, loss = 0.11830368
# Iteration 224, loss = 0.11811785
# Iteration 225, loss = 0.11704386
# Iteration 226, loss = 0.11661180
# Iteration 227, loss = 0.11549870
# Iteration 228, loss = 0.11475528
# Iteration 229, loss = 0.11431790
# Iteration 230, loss = 0.11351851
# Iteration 231, loss = 0.11238060
# Iteration 232, loss = 0.11190008
# Iteration 233, loss = 0.11198318
# Iteration 234, loss = 0.11083560
# Iteration 235, loss = 0.10956460
# Iteration 236, loss = 0.10902534
# Iteration 237, loss = 0.10832664
# Iteration 238, loss = 0.10798185
# Iteration 239, loss = 0.10828979
# Iteration 240, loss = 0.10662582
# Iteration 241, loss = 0.10593970
# Iteration 242, loss = 0.10496950
# Iteration 243, loss = 0.10442123
# Iteration 244, loss = 0.10441831
# Iteration 245, loss = 0.10349875
# Iteration 246, loss = 0.10282694
# Iteration 247, loss = 0.10187370
# Iteration 248, loss = 0.10144363
# Iteration 249, loss = 0.10043886
# Iteration 250, loss = 0.10054863
# Iteration 251, loss = 0.09919776
# Iteration 252, loss = 0.09872106
# Iteration 253, loss = 0.09840694
# Iteration 254, loss = 0.09769884
# Iteration 255, loss = 0.09723497
# Iteration 256, loss = 0.09643298
# Iteration 257, loss = 0.09574369
# Iteration 258, loss = 0.09518038
# Iteration 259, loss = 0.09492790
# Iteration 260, loss = 0.09376573
# Iteration 261, loss = 0.09403607
# Iteration 262, loss = 0.09285547
# Iteration 263, loss = 0.09261216
# Iteration 264, loss = 0.09244007
# Iteration 265, loss = 0.09134614
# Iteration 266, loss = 0.09097495
# Iteration 267, loss = 0.09036563
# Iteration 268, loss = 0.08973112
# Iteration 269, loss = 0.08944059
# Iteration 270, loss = 0.08903320
# Iteration 271, loss = 0.08825954
# Iteration 272, loss = 0.08881331
# Iteration 273, loss = 0.08704190
# Iteration 274, loss = 0.08770046
# Iteration 275, loss = 0.08637232
# Iteration 276, loss = 0.08624365
# Iteration 277, loss = 0.08563467
# Iteration 278, loss = 0.08490841
# Iteration 279, loss = 0.08452357
# Iteration 280, loss = 0.08504715
# Iteration 281, loss = 0.08381123
# Iteration 282, loss = 0.08313314
# Iteration 283, loss = 0.08254994
# Iteration 284, loss = 0.08210358
# Iteration 285, loss = 0.08178796
# Iteration 286, loss = 0.08130282
# Iteration 287, loss = 0.08081454
# Iteration 288, loss = 0.08037503
# Iteration 289, loss = 0.08048717
# Iteration 290, loss = 0.07966663
# Iteration 291, loss = 0.07918990
# Iteration 292, loss = 0.07873297
# Iteration 293, loss = 0.07848620
# Iteration 294, loss = 0.07898607
# Iteration 295, loss = 0.07776208
# Iteration 296, loss = 0.07771893
# Iteration 297, loss = 0.07703762
# Iteration 298, loss = 0.07688595
# Iteration 299, loss = 0.07653337
# Iteration 300, loss = 0.07589252
# Iteration 1, loss = 1.34939337
# Iteration 2, loss = 1.21132792
# Iteration 3, loss = 1.12879465
# Iteration 4, loss = 1.07571699
# Iteration 5, loss = 1.02609859
# Iteration 6, loss = 0.98412871
# Iteration 7, loss = 0.94985622
# Iteration 8, loss = 0.93245657
# Iteration 9, loss = 0.92014997
# Iteration 10, loss = 0.90901439
# Iteration 11, loss = 0.89996746
# Iteration 12, loss = 0.89138969
# Iteration 13, loss = 0.88305902
# Iteration 14, loss = 0.87605542
# Iteration 15, loss = 0.86862202
# Iteration 16, loss = 0.86152548
# Iteration 17, loss = 0.85467553
# Iteration 18, loss = 0.84779751
# Iteration 19, loss = 0.84091089
# Iteration 20, loss = 0.83353346
# Iteration 21, loss = 0.82603282
# Iteration 22, loss = 0.81857613
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 23, loss = 0.81132273
# Iteration 24, loss = 0.80433331
# Iteration 25, loss = 0.79625383
# Iteration 26, loss = 0.78883047
# Iteration 27, loss = 0.78214403
# Iteration 28, loss = 0.77530864
# Iteration 29, loss = 0.76891856
# Iteration 30, loss = 0.76303794
# Iteration 31, loss = 0.75655760
# Iteration 32, loss = 0.75147573
# Iteration 33, loss = 0.74372864
# Iteration 34, loss = 0.73819014
# Iteration 35, loss = 0.73101499
# Iteration 36, loss = 0.72474366
# Iteration 37, loss = 0.71880236
# Iteration 38, loss = 0.71279568
# Iteration 39, loss = 0.70678816
# Iteration 40, loss = 0.70045024
# Iteration 41, loss = 0.69430310
# Iteration 42, loss = 0.68848691
# Iteration 43, loss = 0.68314459
# Iteration 44, loss = 0.67766123
# Iteration 45, loss = 0.67026911
# Iteration 46, loss = 0.66478910
# Iteration 47, loss = 0.65808654
# Iteration 48, loss = 0.65251077
# Iteration 49, loss = 0.64667105
# Iteration 50, loss = 0.64087106
# Iteration 51, loss = 0.63576353
# Iteration 52, loss = 0.63018121
# Iteration 53, loss = 0.62518871
# Iteration 54, loss = 0.61943856
# Iteration 55, loss = 0.61570132
# Iteration 56, loss = 0.60944100
# Iteration 57, loss = 0.60437535
# Iteration 58, loss = 0.59977165
# Iteration 59, loss = 0.59426422
# Iteration 60, loss = 0.58977979
# Iteration 61, loss = 0.58511487
# Iteration 62, loss = 0.58050528
# Iteration 63, loss = 0.57563146
# Iteration 64, loss = 0.57068092
# Iteration 65, loss = 0.56675786
# Iteration 66, loss = 0.56213501
# Iteration 67, loss = 0.55791577
# Iteration 68, loss = 0.55356878
# Iteration 69, loss = 0.54938350
# Iteration 70, loss = 0.54615916
# Iteration 71, loss = 0.54211976
# Iteration 72, loss = 0.53728004
# Iteration 73, loss = 0.53371097
# Iteration 74, loss = 0.52954758
# Iteration 75, loss = 0.52548068
# Iteration 76, loss = 0.52205889
# Iteration 77, loss = 0.51773837
# Iteration 78, loss = 0.51457968
# Iteration 79, loss = 0.51070946
# Iteration 80, loss = 0.50574101
# Iteration 81, loss = 0.50184961
# Iteration 82, loss = 0.49777161
# Iteration 83, loss = 0.49393514
# Iteration 84, loss = 0.48983594
# Iteration 85, loss = 0.48661440
# Iteration 86, loss = 0.48365487
# Iteration 87, loss = 0.47885975
# Iteration 88, loss = 0.47514957
# Iteration 89, loss = 0.47153903
# Iteration 90, loss = 0.46804215
# Iteration 91, loss = 0.46429338
# Iteration 92, loss = 0.46144779
# Iteration 93, loss = 0.45721934
# Iteration 94, loss = 0.45473402
# Iteration 95, loss = 0.45211272
# Iteration 96, loss = 0.44737510
# Iteration 97, loss = 0.44626686
# Iteration 98, loss = 0.44221572
# Iteration 99, loss = 0.44116530
# Iteration 100, loss = 0.43647196
# Iteration 101, loss = 0.43210251
# Iteration 102, loss = 0.42974068
# Iteration 103, loss = 0.42525164
# Iteration 104, loss = 0.42313930
# Iteration 105, loss = 0.41954655
# Iteration 106, loss = 0.41673786
# Iteration 107, loss = 0.41359061
# Iteration 108, loss = 0.41068398
# Iteration 109, loss = 0.40712738
# Iteration 110, loss = 0.40475035
# Iteration 111, loss = 0.40112117
# Iteration 112, loss = 0.39827130
# Iteration 113, loss = 0.39448069
# Iteration 114, loss = 0.39153182
# Iteration 115, loss = 0.38871974
# Iteration 116, loss = 0.38592153
# Iteration 117, loss = 0.38346546
# Iteration 118, loss = 0.37988333
# Iteration 119, loss = 0.37837136
# Iteration 120, loss = 0.37575793
# Iteration 121, loss = 0.37216263
# Iteration 122, loss = 0.37053530
# Iteration 123, loss = 0.36719142
# Iteration 124, loss = 0.36540607
# Iteration 125, loss = 0.36245100
# Iteration 126, loss = 0.36026819
# Iteration 127, loss = 0.35732862
# Iteration 128, loss = 0.35533054
# Iteration 129, loss = 0.35363387
# Iteration 130, loss = 0.35132771
# Iteration 131, loss = 0.34985005
# Iteration 132, loss = 0.34904815
# Iteration 133, loss = 0.34671944
# Iteration 134, loss = 0.34386402
# Iteration 135, loss = 0.34137299
# Iteration 136, loss = 0.33766609
# Iteration 137, loss = 0.33579301
# Iteration 138, loss = 0.33312447
# Iteration 139, loss = 0.33096818
# Iteration 140, loss = 0.32909168
# Iteration 141, loss = 0.32765139
# Iteration 142, loss = 0.32538069
# Iteration 143, loss = 0.32315240
# Iteration 144, loss = 0.32052063
# Iteration 145, loss = 0.31802551
# Iteration 146, loss = 0.31620232
# Iteration 147, loss = 0.31416741
# Iteration 148, loss = 0.31284079
# Iteration 149, loss = 0.31013019
# Iteration 150, loss = 0.31012362
# Iteration 151, loss = 0.30814024
# Iteration 152, loss = 0.30729110
# Iteration 153, loss = 0.30375976
# Iteration 154, loss = 0.30148556
# Iteration 155, loss = 0.29983438
# Iteration 156, loss = 0.29771584
# Iteration 157, loss = 0.29635868
# Iteration 158, loss = 0.29437298
# Iteration 159, loss = 0.29281704
# Iteration 160, loss = 0.29103389
# Iteration 161, loss = 0.28969936
# Iteration 162, loss = 0.28760157
# Iteration 163, loss = 0.28635555
# Iteration 164, loss = 0.28495339
# Iteration 165, loss = 0.28438053
# Iteration 166, loss = 0.28106316
# Iteration 167, loss = 0.27960864
# Iteration 168, loss = 0.27829214
# Iteration 169, loss = 0.27616727
# Iteration 170, loss = 0.27544892
# Iteration 171, loss = 0.27300199
# Iteration 172, loss = 0.27201332
# Iteration 173, loss = 0.27052765
# Iteration 174, loss = 0.26962262
# Iteration 175, loss = 0.26775081
# Iteration 176, loss = 0.26595717
# Iteration 177, loss = 0.26423598
# Iteration 178, loss = 0.26340464
# Iteration 179, loss = 0.26196346
# Iteration 180, loss = 0.26010365
# Iteration 181, loss = 0.25803549
# Iteration 182, loss = 0.25696658
# Iteration 183, loss = 0.25477518
# Iteration 184, loss = 0.25345254
# Iteration 185, loss = 0.25154606
# Iteration 186, loss = 0.25020833
# Iteration 187, loss = 0.24908709
# Iteration 188, loss = 0.24768158
# Iteration 189, loss = 0.24634526
# Iteration 190, loss = 0.24451000
# Iteration 191, loss = 0.24356713
# Iteration 192, loss = 0.24156792
# Iteration 193, loss = 0.24068036
# Iteration 194, loss = 0.23981009
# Iteration 195, loss = 0.23897377
# Iteration 196, loss = 0.23690817
# Iteration 197, loss = 0.23645073
# Iteration 198, loss = 0.23520461
# Iteration 199, loss = 0.23396837
# Iteration 200, loss = 0.23157781
# Iteration 201, loss = 0.23105218
# Iteration 202, loss = 0.22924359
# Iteration 203, loss = 0.22853995
# Iteration 204, loss = 0.22817508
# Iteration 205, loss = 0.22590677
# Iteration 206, loss = 0.22502459
# Iteration 207, loss = 0.22461773
# Iteration 208, loss = 0.22296493
# Iteration 209, loss = 0.22155681
# Iteration 210, loss = 0.22052874
# Iteration 211, loss = 0.21960857
# Iteration 212, loss = 0.21815573
# Iteration 213, loss = 0.21731231
# Iteration 214, loss = 0.21641778
# Iteration 215, loss = 0.21501645
# Iteration 216, loss = 0.21407148
# Iteration 217, loss = 0.21347954
# Iteration 218, loss = 0.21312436
# Iteration 219, loss = 0.21142244
# Iteration 220, loss = 0.21074304
# Iteration 221, loss = 0.20934487
# Iteration 222, loss = 0.20846270
# Iteration 223, loss = 0.20807841
# Iteration 224, loss = 0.20734511
# Iteration 225, loss = 0.20581011
# Iteration 226, loss = 0.20497956
# Iteration 227, loss = 0.20429444
# Iteration 228, loss = 0.20294910
# Iteration 229, loss = 0.20191334
# Iteration 230, loss = 0.20074681
# Iteration 231, loss = 0.19991667
# Iteration 232, loss = 0.19954773
# Iteration 233, loss = 0.19865789
# Iteration 234, loss = 0.19770412
# Iteration 235, loss = 0.19659970
# Iteration 236, loss = 0.19583932
# Iteration 237, loss = 0.19524264
# Iteration 238, loss = 0.19437113
# Iteration 239, loss = 0.19325615
# Iteration 240, loss = 0.19264144
# Iteration 241, loss = 0.19207940
# Iteration 242, loss = 0.19155083
# Iteration 243, loss = 0.19049884
# Iteration 244, loss = 0.18945103
# Iteration 245, loss = 0.18879592
# Iteration 246, loss = 0.18854946
# Iteration 247, loss = 0.18755233
# Iteration 248, loss = 0.18681027
# Iteration 249, loss = 0.18562014
# Iteration 250, loss = 0.18506110
# Iteration 251, loss = 0.18453762
# Iteration 252, loss = 0.18351082
# Iteration 253, loss = 0.18274065
# Iteration 254, loss = 0.18227009
# Iteration 255, loss = 0.18165349
# Iteration 256, loss = 0.18072655
# Iteration 257, loss = 0.18028114
# Iteration 258, loss = 0.17981059
# Iteration 259, loss = 0.17892353
# Iteration 260, loss = 0.17846746
# Iteration 261, loss = 0.17771782
# Iteration 262, loss = 0.17706442
# Iteration 263, loss = 0.17636296
# Iteration 264, loss = 0.17578585
# Iteration 265, loss = 0.17532830
# Iteration 266, loss = 0.17459735
# Iteration 267, loss = 0.17429910
# Iteration 268, loss = 0.17352782
# Iteration 269, loss = 0.17280136
# Iteration 270, loss = 0.17231206
# Iteration 271, loss = 0.17167546
# Iteration 272, loss = 0.17147888
# Iteration 273, loss = 0.17056200
# Iteration 274, loss = 0.17038120
# Iteration 275, loss = 0.16960821
# Iteration 276, loss = 0.16913191
# Iteration 277, loss = 0.16864970
# Iteration 278, loss = 0.16801649
# Iteration 279, loss = 0.16770316
# Iteration 280, loss = 0.16713549
# Iteration 281, loss = 0.16674835
# Iteration 282, loss = 0.16626648
# Iteration 283, loss = 0.16570079
# Iteration 284, loss = 0.16497692
# Iteration 285, loss = 0.16451890
# Iteration 286, loss = 0.16402682
# Iteration 287, loss = 0.16358194
# Iteration 288, loss = 0.16353259
# Iteration 289, loss = 0.16308261
# Iteration 290, loss = 0.16271235
# Iteration 291, loss = 0.16236825
# Iteration 292, loss = 0.16179451
# Iteration 293, loss = 0.16083213
# Iteration 294, loss = 0.16067602
# Iteration 295, loss = 0.15994611
# Iteration 296, loss = 0.15971995
# Iteration 297, loss = 0.15906787
# Iteration 298, loss = 0.15872612
# Iteration 299, loss = 0.15881515
# Iteration 300, loss = 0.15757055
#
# --- Evaluación Modelo 1 ---
# Accuracy : 0.8253424657534246
# Precision: 0.8285163827293871
# Recall   : 0.8253424657534246
# F1-score : 0.8264965106978874
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         Cara       0.88      0.87      0.87        99
#    Económica       0.88      0.84      0.86        97
#   Intermedia       0.73      0.77      0.75        96
#
#     accuracy                           0.83       292
#    macro avg       0.83      0.82      0.83       292
# weighted avg       0.83      0.83      0.83       292
#
# Confusion Matrix:
#  [[86  0 13]
#  [ 1 81 15]
#  [11 11 74]]
#
# --- Evaluación Modelo 2 ---
# Accuracy : 0.8116438356164384
# Precision: 0.8172359595197864
# Recall   : 0.8116438356164384
# F1-score : 0.8134497769526572
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         Cara       0.88      0.84      0.86        99
#    Económica       0.86      0.81      0.84        97
#   Intermedia       0.71      0.78      0.74        96
#
#     accuracy                           0.81       292
#    macro avg       0.82      0.81      0.81       292
# weighted avg       0.82      0.81      0.81       292
#
# Confusion Matrix:
#  [[83  0 16]
#  [ 3 79 15]
#  [ 8 13 75]]
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
modelos = [
    ("Modelo 1 (5,3 – tanh)", modelo1),
    ("Modelo 2 (10,5 – relu)", modelo2)
]


clases = modelo1.named_steps['mlpclassifier'].classes_

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, (nombre, modelo) in zip(axes, modelos):
 
    y_pred = modelo.predict(X_test)
  
    cm = confusion_matrix(y_test, y_pred, labels=clases)

    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Blues',
        cbar=False,
        xticklabels=clases,
        yticklabels=clases,
        ax=ax
    )
    ax.set_title(f"Matriz de Confusión\n{nombre}")
    ax.set_xlabel("Predicción")
    ax.set_ylabel("Valor Real")

plt.tight_layout()

# %% [markdown]
# Comparando ambos modelos, el Modelo 1 (arquitectura 5–3 con función de activación tanh) obtuvo un 82.5 % de accuracy frente al 81.2 % del Modelo 2 (10–5 con activación relu), además de mejores precision (82.9 % vs 81.7 %) y F1-score (82.6 % vs 81.3 %), y su matriz de confusión muestra menos confusiones entre las tres categorías (especialmente “Cara” y “Económica”). El Modelo 1 también convergió correctamente en 300 iteraciones con un loss más bajo, mientras que el Modelo 2 no llegó a converger en ese mismo número de iteraciones. En conjunto, el Modelo 1 ofrece un mejor equilibrio entre efectividad y eficiencia, cometiendo menos errores y convergiendo de forma más estable.

# %%
y_train_pred = modelo1.predict(X_train)
acc_train = accuracy_score(y_train, y_train_pred)


y_test_pred = modelo1.predict(X_test)
acc_test = accuracy_score(y_test, y_test_pred)

print(f"Accuracy entrenamiento: {acc_train:.3f}")
print(f"Accuracy prueba     : {acc_test:.3f}")
# Out:
# Accuracy entrenamiento: 0.992
# Accuracy prueba     : 0.825

# %% [markdown]
# La diferencia entre Accuracy entrenamiento (0.992) y Accuracy prueba (0.825) es muy grande puede ser un indicio de sobreajuste

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc  = le.transform(y_test)

# Pipeline con early stopping
pipe = make_pipeline(
    preprocesador,
    MLPClassifier(
        solver="adam",
        early_stopping=True,
        validation_fraction=0.2,
        n_iter_no_change=10,
        max_iter=1000,
        random_state=42
    )
)

# GridSearch como antes
grid = GridSearchCV(
    pipe,
    param_grid,
    cv=5,
    scoring="f1_weighted",
    n_jobs=-1,
    verbose=2
)

grid.fit(X_train, y_train_enc)

print("Mej prefs:", grid.best_params_)
print("Mejor F1 (CV):", grid.best_score_)

best = grid.best_estimator_
print("Acc training:", best.score(X_train, y_train_enc))
print("Acc testing :", best.score(X_test,  y_test_enc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 21
#       6 pipe = make_pipeline(
#       7     preprocesador,
#       8     MLPClassifier(
#    (...)
#      15     )
#      16 )
#      18 # GridSearch como antes
#      19 grid = GridSearchCV(
#      20     pipe,
# ---> 21     param_grid,
#      22     cv=5,
#      23     scoring="f1_weighted",
#      24     n_jobs=-1,
#      25     verbose=2
#      26 )
#      28 grid.fit(X_train, y_train_enc)
#      30 print("Mej prefs:", grid.best_params_)
#
# NameError: name 'param_grid' is not defined

# %%
X_reg = df_clean.drop(['Id', 'SalePrice', 'PriceCategory'], axis=1)
y_reg = df_clean['SalePrice']

from sklearn.model_selection import train_test_split
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg,
    y_reg,
    test_size=0.20,
    random_state=42
)

print("X_train_reg:", X_train_reg.shape)
print("X_test_reg :", X_test_reg.shape)
print("y_train_reg distribuciones:\n", y_train_reg.describe())
# Out:
# X_train_reg: (1168, 79)
# X_test_reg : (292, 79)
# y_train_reg distribuciones:
#  count      1168.000000
# mean     181441.541952
# std       77263.583862
# min       34900.000000
# 25%      130000.000000
# 50%      165000.000000
# 75%      214925.000000
# max      745000.000000
# Name: SalePrice, dtype: float64

# %%
# Creando dos modelos de regresión con diferentes topologías y funciones de activación
print("Entrenando modelos de regresión...")

# Modelo 1: Configuración simple
inicio = time.time()
regressor1 = make_pipeline(
    preprocesador,
    MLPRegressor(
        hidden_layer_sizes=(10, 5),
        activation="tanh",
        solver="adam",
        max_iter=500,
        random_state=42
    )
)
regressor1.fit(X_train_reg, y_train_reg)
tiempo_modelo1 = time.time() - inicio
print(f"Tiempo de entrenamiento modelo 1: {tiempo_modelo1:.2f} segundos")
# Out:
# Entrenando modelos de regresión...
# Tiempo de entrenamiento modelo 1: 1.29 segundos
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Modelo 2: Configuración más compleja
inicio = time.time()
regressor2 = make_pipeline(
    preprocesador,
    MLPRegressor(
        hidden_layer_sizes=(20, 10, 5),
        activation="relu",
        solver="adam",
        max_iter=500,
        alpha=0.001,
        random_state=42
    )
)
regressor2.fit(X_train_reg, y_train_reg)
tiempo_modelo2 = time.time() - inicio
print(f"Tiempo de entrenamiento modelo 2: {tiempo_modelo2:.2f} segundos")
# Out:
# Tiempo de entrenamiento modelo 2: 1.69 segundos
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# Los resultados del entrenamiento de los dos modelos de regresión con redes neuronales muestran una diferencia notable en los tiempos de procesamiento. El Modelo 1, con una arquitectura más simple de dos capas ocultas (10 y 5 neuronas) y función de activación tanh, completó su entrenamiento en apenas 2.80 segundos. Por otro lado, el Modelo 2, con una topología más compleja de tres capas ocultas (20, 10 y 5 neuronas) y función de activación relu, requirió más tiempo, finalizando en 4.18 segundos. Esta diferencia era esperada debido a la mayor complejidad estructural del segundo modelo, que implica un aumento en el número de parámetros a optimizar durante el entrenamiento. Sin embargo, ambos tiempos son relativamente rápidos, lo que sugiere que las redes neuronales pueden ser una alternativa eficiente para problemas de regresión de precios inmobiliarios, incluso con arquitecturas moderadamente complejas.

# %%
# Evaluación de los modelos
resultados_modelo1 = evaluar_modelo_regresion(
    regressor1, X_train_reg, y_train_reg, X_test_reg, y_test_reg, 
    "Modelo 1 (10,5 - tanh)"
)

resultados_modelo2 = evaluar_modelo_regresion(
    regressor2, X_train_reg, y_train_reg, X_test_reg, y_test_reg, 
    "Modelo 2 (20,10,5 - relu)"
)

# Comparativa visual
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Gráfico de dispersión para el Modelo 1
axes[0].scatter(resultados_modelo1['y_test'], resultados_modelo1['y_pred'], alpha=0.5)
axes[0].plot([y_test_reg.min(), y_test_reg.max()], [y_test_reg.min(), y_test_reg.max()], 'r--')
axes[0].set_xlabel('Precio real')
axes[0].set_ylabel('Precio predicho')
axes[0].set_title(f"Modelo 1 (10,5 - tanh)\nR² = {resultados_modelo1['r2_test']:.4f}")

# Gráfico de dispersión para el Modelo 2
axes[1].scatter(resultados_modelo2['y_test'], resultados_modelo2['y_pred'], alpha=0.5)
axes[1].plot([y_test_reg.min(), y_test_reg.max()], [y_test_reg.min(), y_test_reg.max()], 'r--')
axes[1].set_xlabel('Precio real')
axes[1].set_ylabel('Precio predicho')
axes[1].set_title(f"Modelo 2 (20,10,5 - relu)\nR² = {resultados_modelo2['r2_test']:.4f}")

plt.tight_layout()
plt.show()

# Determinar el mejor modelo
if resultados_modelo1['r2_test'] > resultados_modelo2['r2_test']:
    mejor_modelo_reg = regressor1
    mejor_resultado_reg = resultados_modelo1
    print("\nEl Modelo 1 (10,5 - tanh) tuvo mejor desempeño")
else:
    mejor_modelo_reg = regressor2
    mejor_resultado_reg = resultados_modelo2
    print("\nEl Modelo 2 (20,10,5 - relu) tuvo mejor desempeño")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       3 warnings.filterwarnings('ignore', category=ConvergenceWarning)
#       4 # Evaluación de los modelos
# ----> 5 resultados_modelo1 = evaluar_modelo_regresion(
#       6     regressor1, X_train_reg, y_train_reg, X_test_reg, y_test_reg,
#       7     "Modelo 1 (10,5 - tanh)"
#       8 )
#      10 resultados_modelo2 = evaluar_modelo_regresion(
#      11     regressor2, X_train_reg, y_train_reg, X_test_reg, y_test_reg,
#      12     "Modelo 2 (20,10,5 - relu)"
#      13 )
#      15 # Comparativa visual
#
# NameError: name 'evaluar_modelo_regresion' is not defined

# %% [markdown]
# Los resultados de evaluación muestran una diferencia significativa entre los dos modelos de regresión. El Modelo 1 (topología 10,5 con activación tanh) presenta métricas extremadamente pobres, con un R² negativo tanto en entrenamiento (-5.5182) como en prueba (-4.1689), y valores de RMSE alrededor de $197,000-$199,000, indicando que este modelo no solo falla en capturar la relación entre las variables, sino que tiene un desempeño considerablemente peor que simplemente predecir la media. En contraste, el Modelo 2 (topología 20,10,5 con activación relu) muestra un rendimiento significativamente superior, con un R² de 0.8291 en entrenamiento y 0.8407 en prueba, y un RMSE de aproximadamente $32,000-$35,000, lo que representa una mejora en precisión. La activación ReLU combinada con una arquitectura más profunda parece ser mucho más adecuada para capturar las relaciones no lineales complejas presentes en los datos de precios inmobiliarios, demostrando así que la elección apropiada de la arquitectura y función de activación es crucial en el rendimiento de los modelos de redes neuronales.

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=ConvergenceWarning)
from sklearn.exceptions import ConvergenceWarning 

def plot_learning_curve(estimator, X, y, title, ax, train_sizes=np.linspace(0.1, 1.0, 5)):
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, 
        train_sizes=train_sizes,
        cv=5, 
        scoring='neg_mean_squared_error',
        n_jobs=-1
    )
    
    # Calcular estadísticas
    train_scores_mean = -np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = -np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    # Calcular RMSE
    train_rmse_mean = np.sqrt(train_scores_mean)
    test_rmse_mean = np.sqrt(test_scores_mean)
    
    # Graficar curvas de aprendizaje
    ax.fill_between(train_sizes, 
                    train_rmse_mean - train_scores_std,
                    train_rmse_mean + train_scores_std, 
                    alpha=0.1, color="r")
    ax.fill_between(train_sizes, 
                    test_rmse_mean - test_scores_std,
                    test_rmse_mean + test_scores_std, 
                    alpha=0.1, color="g")
    ax.plot(train_sizes, train_rmse_mean, 'o-', color="r", label="Entrenamiento")
    ax.plot(train_sizes, test_rmse_mean, 'o-', color="g", label="Validación")
    ax.set_xlabel("Tamaño del conjunto de entrenamiento")
    ax.set_ylabel("RMSE")
    ax.set_title(title)
    ax.legend(loc="best")
    ax.grid(True)

# Análisis de sobreajuste mediante curvas de aprendizaje
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Curva de aprendizaje para Modelo 1
plot_learning_curve(
    regressor1, 
    X_train_reg, 
    y_train_reg, 
    "Curva de aprendizaje - Modelo 1 (10,5 - tanh)",
    axes[0]
)

# Curva de aprendizaje para Modelo 2
plot_learning_curve(
    regressor2, 
    X_train_reg, 
    y_train_reg, 
    "Curva de aprendizaje - Modelo 2 (20,10,5 - relu)",
    axes[1]
)

plt.tight_layout()
plt.show()
# Out:
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['PoolQC']. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['PoolQC']. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['PoolQC']. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['PoolQC']. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['PoolQC']. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['PoolQC']. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/bianca_cal/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# Las curvas de aprendizaje revelan información importante sobre el comportamiento de ambos modelos. Se observa que el Modelo 1 (10,5 - tanh) muestra valores de RMSE cercanos a cero tanto para entrenamiento como validación, pero con bandas de desviación estándar extremadamente amplias, especialmente con conjuntos de entrenamiento pequeños. Esta inconsistencia y variabilidad sugiere que el modelo con activación tanh tiene dificultades para generalizar los patrones en los datos. Por otro lado, el Modelo 2 (20,10,5 - relu) presenta un comportamiento similar en términos de las líneas principales de RMSE, pero con bandas de desviación más controladas a medida que aumenta el tamaño del conjunto de entrenamiento. La advertencia de convergencia indica que el Modelo 1 no logró converger dentro del número máximo de iteraciones (500), lo que explica parcialmente su mal rendimiento. Aunque ambas curvas no muestran la típica brecha entre entrenamiento y validación característica del sobreajuste, la pobre capacidad predictiva del Modelo 1 y la mayor estabilidad del Modelo 2 confirman que la arquitectura con ReLU es una elección más apropiada para este conjunto de datos.
